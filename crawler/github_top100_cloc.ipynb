# %%
import requests
import subprocess
import time,os
import concurrent.futures
import json
import urllib,zipfile

STORGE_PATH = "/home/dsr/project/github_top/"
input_filename = "./github_top_star_url_list100.txt"
output_filename = "github_repos_codeline.txt"

# %%
def get_name(repo_url):
    return repo_url.split('/')[-1].replace('.git', '')

# Note: The size of the repository can be significantly increased by the .git directory (e.g., in the Linux repository). 
# To avoid this, you can download the repository as a zip file using curl.

def download_zip(url, repo_path, zip_path):
    urllib.request.urlretrieve(url, zip_path)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(repo_path)
    os.remove(zip_path)

def download_repo(repo_url):
    repo_name = get_name(repo_url)
    repo_path = os.path.join(STORGE_PATH, repo_name)

    if not os.path.exists(repo_path):
        os.makedirs(repo_path)
        print(f"Downloading {repo_name} as zip")
        
        zip_path = os.path.join(STORGE_PATH, f"{repo_name}.zip")
        branch_list = ["main", "master"]
        
        for branch in branch_list:
            try:
                zip_url = f"{repo_url.rstrip('.git')}/archive/refs/heads/{branch}.zip"
                download_zip(zip_url, repo_path, zip_path)
                print(f"Downloaded {repo_name} from branch {branch}")
                break
            except Exception as e:
                print(f"Failed to download from branch {branch}: {e}")
                if branch == branch_list[-1]:
                    raise Exception(f"Failed to download repository from all known branches: {repo_url}")
    else:
        if len(os.listdir(repo_path)) <= 1:
            print(f"Deleting empty directory {repo_name}: cmd = \"rm -rf {repo_path}\"")
            subprocess.run(['rm', '-rf', repo_path], check=True)
            time.sleep(3)
            download_repo(repo_url)
        else:
            pass
            # print(f"{repo_name} already exists")

# %%
with open(input_filename, 'r') as file:
    repo_urls = [line.strip() for line in file]

# download all repos
for repo_url in repo_urls:
    download_repo(repo_url)
# Out:
# Deleting empty directory iptv: cmd = "rm -rf /home/dsr/project/github_top/iptv"
# Downloading iptv as zip
# Failed to download from branch main: HTTP Error 404: Not Found
# Downloaded iptv from branch master

# %%
counts = {}
def count_lines_of_repo(repo_url):
    if repo_url in counts: return
    repo_name = get_name(repo_url)
    repo_path = STORGE_PATH+repo_name

    stdout_str_json = subprocess.run(["cloc", repo_path, "--json"], capture_output=True, text=True).stdout
    result = json.loads(stdout_str_json)

    counts[repo_url] = result["SUM"]["code"]
    print(f"{get_name(repo_url):<30} : {counts[repo_url]:>10}")

# %%
# count all repos by cloc tools
with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    futures = [executor.submit(count_lines_of_repo, repo_url) for repo_url in repo_urls]
    for future in concurrent.futures.as_completed(futures):
        future.result()  # 等待所有线程完成
# Out:
# build-your-own-x               :        452
# project-based-learning         :        681
# awesome                        :       1119
# awesome-python                 :       1071
# awesome-selfhosted             :       1785
# public-apis                    :       2917
# 996.ICU                        :       3847
# system-design-primer           :      10382
# You-Dont-Know-JS               :      12437
# free-programming-books         :      20365
# coding-interview-university    :      49529
# computer-science               :       1489
# gitignore                      :        158
# javascript-algorithms          :      45420
# the-art-of-command-line        :       6503
# the-book-of-secret-knowledge   :       3418
# javascript                     :       7173
# vue                            :      74391
# CS-Notes                       :      57020
# ohmyzsh                        :      62127
# JavaGuide                      :      59810
# awesome-go                     :       5004
# Python-100-Days                :      97028
# stable-diffusion-webui         :      36763
# bootstrap                      :     130591
# Python                         :      49366
# free-programming-books-zh_CN   :        837
# fucking-algorithm              :      86482
# d3                             :      16594
# 30-seconds-of-code             :      56384
# awesome-chatgpt-prompts        :        896
# tech-interview-handbook        :     113162
# scrcpy                         :      30188
# axios                          :      65997
# youtube-dl                     :     140690
# developer-roadmap              :     530347
# nodebestpractices              :      32636
# electron                       :     204235
# AutoGPT                        :     708593
# create-react-app               :     124611
# react                          :     575343
# GitHub-Chinese-Top-Charts      :      18463
# PowerToys                      :     316180
# clean-code-javascript          :       1850
# terminal                       :     372067
# ant-design                     :     212613
# java-design-patterns           :     110765
# vue-element-admin              :      19545
# react-native                   :     541423
# three.js                       :     779026
# HelloGitHub                    :      20589
# free-for-dev                   :       1829
# papers-we-love                 :       1228
# puppeteer                      :     128588
# thefuck                        :      11263
# frp                            :      29368
# Microsoft-Activation-Scripts   :      19635
# animate.css                    :       8246
# Web-Dev-For-Beginners          :     119651
# tailwindcss                    :      33584
# realworld                      :      65137
# flutter                        :    1458718
# iptv                           :      20941
# Awesome-Hacking                :        119
# storybook                      :     332340
# tauri                          :      87352
# every-programmer-should-know   :        280
# laravel                        :       1155
# svelte                         :     162098
# deno                           :     763920
# angular                        :     850923
# langchain                      :     472961
# nvm                            :      12568
# hello-algo                     :     158996
# transformers                   :    1056913
# material-ui                    :     934444
# django                         :     644182
# FiraCode                       :       7784
# app-ideas                      :       3647
# mall                           :     133054
# gin                            :      17850
# neovim                         :     934268
# LeetCodeAnimation              :      12886
# advanced-java                  :      83344
# excalidraw                     :     130971
# vscode                         :    1632571
# next.js                        :    1251158
# bitcoin                        :     714469
# models                         :     435332
# rust                           :    2005444
# opencv                         :    2451027
# godot                          :    3503874
# pytorch                        :    2298647
# tensorflow                     :    4168844
# freeCodeCamp                   :    5711627
# go                             :    2109603
# node                           :    8289565
# kubernetes                     :    4449351
# linux                          :   27344482
# TypeScript                     :    2811611

# %%
sorted_results = sorted(counts.items(), key=lambda x: x[1], reverse=True)
formatted_lines = []
for repo_url,count_lines in sorted_results:
    formatted_line = f"{get_name(repo_url):<30} : {count_lines:>10}"
    formatted_lines.append(formatted_line)
with open(output_filename,"w") as file:
    for formatted_line in formatted_lines:
        file.write(formatted_line + '\n')

print(formatted_lines)
# Out:
# ['linux                          :   27344482', 'node                           :    8289565', 'freeCodeCamp                   :    5711627', 'kubernetes                     :    4449351', 'tensorflow                     :    4168844', 'godot                          :    3503874', 'TypeScript                     :    2811611', 'opencv                         :    2451027', 'pytorch                        :    2298647', 'go                             :    2109603', 'rust                           :    2005444', 'vscode                         :    1632571', 'flutter                        :    1458718', 'next.js                        :    1251158', 'transformers                   :    1056913', 'material-ui                    :     934444', 'neovim                         :     934268', 'angular                        :     850923', 'three.js                       :     779026', 'deno                           :     763920', 'bitcoin                        :     714469', 'AutoGPT                        :     708593', 'django                         :     644182', 'react                          :     575343', 'react-native                   :     541423', 'developer-roadmap              :     530347', 'langchain                      :     472961', 'models                         :     435332', 'terminal                       :     372067', 'storybook                      :     332340', 'PowerToys                      :     316180', 'ant-design                     :     212613', 'electron                       :     204235', 'svelte                         :     162098', 'hello-algo                     :     158996', 'youtube-dl                     :     140690', 'mall                           :     133054', 'excalidraw                     :     130971', 'bootstrap                      :     130591', 'puppeteer                      :     128588', 'create-react-app               :     124611', 'Web-Dev-For-Beginners          :     119651', 'tech-interview-handbook        :     113162', 'java-design-patterns           :     110765', 'Python-100-Days                :      97028', 'tauri                          :      87352', 'fucking-algorithm              :      86482', 'advanced-java                  :      83344', 'vue                            :      74391', 'axios                          :      65997', 'realworld                      :      65137', 'ohmyzsh                        :      62127', 'JavaGuide                      :      59810', 'CS-Notes                       :      57020', '30-seconds-of-code             :      56384', 'coding-interview-university    :      49529', 'Python                         :      49366', 'javascript-algorithms          :      45420', 'stable-diffusion-webui         :      36763', 'tailwindcss                    :      33584', 'nodebestpractices              :      32636', 'scrcpy                         :      30188', 'frp                            :      29368', 'iptv                           :      20941', 'HelloGitHub                    :      20589', 'free-programming-books         :      20365', 'Microsoft-Activation-Scripts   :      19635', 'vue-element-admin              :      19545', 'GitHub-Chinese-Top-Charts      :      18463', 'gin                            :      17850', 'd3                             :      16594', 'LeetCodeAnimation              :      12886', 'nvm                            :      12568', 'You-Dont-Know-JS               :      12437', 'thefuck                        :      11263', 'system-design-primer           :      10382', 'animate.css                    :       8246', 'FiraCode                       :       7784', 'javascript                     :       7173', 'the-art-of-command-line        :       6503', 'awesome-go                     :       5004', '996.ICU                        :       3847', 'app-ideas                      :       3647', 'the-book-of-secret-knowledge   :       3418', 'public-apis                    :       2917', 'cle ...
